# %%
a = [1,3,5,7,9]
print(a[2:4])
# Out:
# [5, 7]

# %%
b = [[1, 3, 5, 7, 9], [2, 4, 6, 8, 10]]
print(b[0])
print(b[1][2:4])
# Out:
# [1, 3, 5, 7, 9]

# %%
a = [1,3,5,7,9] 
b = [3,5,6,7,9]
c = a + b
print (c)
